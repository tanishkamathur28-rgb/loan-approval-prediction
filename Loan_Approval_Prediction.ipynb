# %% [markdown]
# ## **Loan Approval Prediction using Support Vector Machine**

# %% [markdown]
# **Problem Statement**
#
# <small>
# The objective of this project is to develop a machine learning model that predicts whether a loan application is likely to be approved based on an applicant's demographic and financial information.

# %% [markdown]
# **Importing Libraries**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score, f1_score,precision_score, recall_score, classification_report, confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# **Data Import**

# %%
# Loading the dataset to pandas DataFrame
loan_dataset = pd.read_csv("train.csv")

# %% [markdown]
# **Data Overview**

# %%
type(loan_dataset)
# Out:
# pandas.DataFrame

# %%
# printing the first 5 rows of the dataset
loan_dataset.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
loan_dataset.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
loan_dataset.shape
# Out:
# (614, 13)

# %%
loan_dataset.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# ****Data Preprocessing****

# %%
# number of missing values in each column
loan_dataset.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
# dropping the missing values
loan_dataset = loan_dataset.dropna()

# %%
# number of missing values in each column
loan_dataset.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
loan_dataset.shape
# Out:
# (480, 13)

# %%
# Label Encoding
loan_dataset.replace({"Loan_Status":{'N':0,'Y':1}},inplace=True)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
# Dependent column values
loan_dataset['Dependents'].value_counts()
# Out:
# Dependents
# 0     274
# 2      85
# 1      80
# 3+     41
# Name: count, dtype: int64

# %%
# replacing the value of 3+ to 4 in the 'Dependents' column
loan_dataset.replace(to_replace = '3+', value = 4, inplace=True)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes          4      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
# dependent column values
loan_dataset["Dependents"] = loan_dataset["Dependents"].astype(int)

# %%
# Convert categorical columns to numerical values
loan_dataset.replace({'Married':{'No':0,'Yes':1}, 
                      'Gender':{'Male':1,'Female':0}, 
                      'Self_Employed':{'No':0,'Yes':1}, 
                      'Property_Area':{'Rural':0,'Semiurban':1,'Urban':2}, 
                      'Education':{'Graduate':1,'Not Graduate':0}}, 
                     inplace=True)
# Out:
#       Loan_ID Gender Married  Dependents Education Self_Employed  \
# 1    LP001003      1       1           1         1             0
# 2    LP001005      1       1           0         1             1
# 3    LP001006      1       1           0         0             0
# 4    LP001008      1       0           0         1             0
# 5    LP001011      1       1           2         1             1
# ..        ...    ...     ...         ...       ...           ...
# 609  LP002978      0       0           0         1             0
# 610  LP002979      1       1           4         1             0
# 611  LP002983      1       1           1         1             0
# 612  LP002984      1       1           2         1             0
# 613  LP002990      0       0           0         1             1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1               4583             1508.0       128.0             360.0
# ...

# %%
# Property area column values
loan_dataset['Property_Area'].value_counts()
# Out:
# Property_Area
# 1    191
# 2    150
# 0    139
# Name: count, dtype: int64

# %%
loan_dataset.dtypes
# Out:
# Loan_ID                  str
# Gender                object
# Married               object
# Dependents             int64
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
# Convert categorical columns to integer type
categorical_cols = ["Gender", "Married", "Dependents",
                    "Education", "Self_Employed", "Property_Area"]

loan_dataset[categorical_cols] = loan_dataset[categorical_cols].astype(int)

# %%
print(loan_dataset.dtypes)
# Out:
# Loan_ID                  str
# Gender                 int64
# Married                int64
# Dependents             int64
# Education              int64
# Self_Employed          int64
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area          int64
# Loan_Status           object
# dtype: object

# %% [markdown]
# **Data Visualization**

# %%
# education and loan status visualization
sns.countplot(x='Education', hue='Loan_Status', data=loan_dataset)
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
# marital status and loan status visualization
sns.countplot(x='Married', hue='Loan_Status', data=loan_dataset)
# Out:
# <Axes: xlabel='Married', ylabel='count'>

# %%
# gender and loan status visualization
sns.countplot(x='Gender', hue='Loan_Status', data=loan_dataset)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
# self-employed and loan status visualization
sns.countplot(x='Self_Employed', hue='Loan_Status', data=loan_dataset)
# Out:
# <Axes: xlabel='Self_Employed', ylabel='count'>

# %% [markdown]
# **Feature Selection**

# %%
# separating the data and labels
X = loan_dataset.drop(columns=['Loan_ID', 'Loan_Status'])
Y = loan_dataset['Loan_Status'].astype(int)

# %%
print(X)
print(Y)
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 1         1        1           1          1              0             4583
# 2         1        1           0          1              1             3000
# 3         1        1           0          0              0             2583
# 4         1        0           0          1              0             6000
# 5         1        1           2          1              1             5417
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          1              0             2900
# 610       1        1           4          1              0             4106
# 611       1        1           1          1              0             8072
# 612       1        1           2          1              0             7583
# 613       0        0           0          1              1             4583
#
# ...

# %% [markdown]
# **Train Test Split**

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (480, 11) (432, 11) (48, 11)

# %% [markdown]
# **Model Training**

# %% [markdown]
# Support Vector Machine Model

# %%
classifier = svm.SVC(kernel='linear')

# %%
# training the SVM model
classifier.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# **Model Evaluation**

# %% [markdown]
# **Accuracy Score**

# %%
# accuracy score on the training data
X_train_prediction = classifier.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print(f'Accuracy score on training data: {training_data_accuracy}')
# Out:
# Accuracy score on training data: 0.7986111111111112

# %%
# accuracy score on the testing data
X_test_prediction = classifier.predict(X_test)
testing_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print(f'Accuracy score on testing data: {testing_data_accuracy}')
# Out:
# Accuracy score on testing data: 0.8333333333333334

# %% [markdown]
# **Performance Metrics**

# %%
# Training Performance
print("Training Performance")
print("="*50)

print(f"Accuracy : {accuracy_score(Y_train, X_train_prediction):.4f}")
print(f"Precision: {precision_score(Y_train, X_train_prediction):.4f}")
print(f"Recall   : {recall_score(Y_train, X_train_prediction):.4f}")
print(f"F1 Score : {f1_score(Y_train, X_train_prediction):.4f}")
# Out:
# Training Performance
# ...
# Accuracy : 0.7986
# Precision: 0.7804
# Recall   : 0.9866
# F1 Score : 0.8715

# %%
# Testing Performance
print("Testing Performance")
print("="*50)

print(f"Accuracy : {accuracy_score(Y_test, X_test_prediction):.4f}")
print(f"Precision: {precision_score(Y_test, X_test_prediction):.4f}")
print(f"Recall   : {recall_score(Y_test, X_test_prediction):.4f}")
print(f"F1 Score : {f1_score(Y_test, X_test_prediction):.4f}")
# Out:
# Testing Performance
# ...
# Accuracy : 0.8333
# Precision: 0.8378
# Recall   : 0.9394
# F1 Score : 0.8857

# %% [markdown]
# **Classification Report**

# %%
# Classification Report
print(f"**Classification Report**")
print(classification_report(Y_test, X_test_prediction))
# Out:
# **Classification Report**
#               precision    recall  f1-score   support
#
#            0       0.82      0.60      0.69        15
#            1       0.84      0.94      0.89        33
#
#     accuracy                           0.83        48
#    macro avg       0.83      0.77      0.79        48
# weighted avg       0.83      0.83      0.83        48

# %% [markdown]
# **Confusion Matrix**

# %%
cm = confusion_matrix(Y_test, X_test_prediction)

print(cm)

ConfusionMatrixDisplay(confusion_matrix=cm).plot()
# Out:
# [[ 9  6]
#  [ 2 31]]

# %% [markdown]
# **Predictive system**

# %%
input_data = (1, 1, 0, 1, 0, 5000, 1500, 120, 360, 1, 2)

# %%
# convert it into a NumPy array
input_data_array = np.asarray(input_data)

# %%
# reshape the array
input_data_reshaped = input_data_array.reshape(1, -1)

# %%
# Prediction
prediction = classifier.predict(input_data_reshaped)
print(prediction)
# Out:
# [1]
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
if prediction[0] == 1:
    print("Loan Approved")
else:
    print("Loan Rejected")
# Out:
# Loan Approved

# %% [markdown]
# **Key Takeaways**

# %% [markdown]
# <small>
#
# * Data preprocessing played a crucial role in improving model performance.
#
# * The SVM model achieved good predictive performance on unseen data.
#
# * The developed model can assist in supporting loan approval decisions.
